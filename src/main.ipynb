# %%
from dotenv import load_dotenv
from openai import OpenAI
import json
import os 
import requests
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override = True)
gemini_api = os.getenv("GOOGLE_API_KEY")
gemini_model = "gemini_2.5_flash"
gemini = OpenAI(api_key=gemini_api, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")

# %%
pushover_user = os.getenv("PUSHOVER_USER")
pushover_token = os.getenv("PUSHOVER_TOKEN")

def pushover(message): 
    response = requests.post(
    "https://api.pushover.net/1/messages.json",
    data={
        "token": pushover_token,
        "user": pushover_user,
        "message": message,
    },
    )
    
    if response.status_code != 200:
        print("Pushover failed:", response.text)
    else:
        print("Pushover sent successfully.")

# %%
pushover("Hello Demo!!!")
# Out:
# Pushover sent successfully.

# %%
def record_user_details(email, name = 'Unknown'):
